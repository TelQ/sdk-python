# %% [markdown]
# # Python SDK

# %%
import os
from telq import TelQTelecomAPI
telq_api = TelQTelecomAPI()

# %% [markdown]
# ## Authenticate App Id and Key by instantiating the class
# - If no error occured when the class is instantiated, then the token has been validated

# %%
telq_api.authenticate(api_id="APP_ID", api_key="APP_KEY")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/lecodage/telq/python_sdk/telq/__init__.py:123, in TelQTelecomAPI.authenticate(self, api_id, api_key)
#     120 try:
#     121     # if the user has been authenticated before
#     122     # and its within 24 hours since the last time the user was authenticated
# --> 123     if (dt.datetime.utcnow() - self._last_time_authenticated) < dt.timedelta(
#     124         days=1
#     125     ):
#     126         print("Already authenticated")
#
# AttributeError: 'TelQTelecomAPI' object has no attribute '_last_time_authenticated'
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# File ~/lecodage/telq/python_sdk/telq/authentication/__init__.py:69, in Authentication._authenticate_user(self)
#      68 try:
# ---> 69     response.raise_for_status()
#      70 except requests.exceptions.HTTPError as e:
#
# File ~/opt/miniconda3/envs/pypi/lib/python3.8/site-packages/requests/models.py:960, in Response.raise_for_status(self)
#     959 if http_error_msg:
# --> 960     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.telqtele.com/v2.1/client/token
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /Users/prameshbajracharya/lecodage/telq/python_sdk/example_notebook.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/prameshbajracharya/lecodage/telq/python_sdk/example_notebook.ipynb#ch0000003?line=0'>1</a> telq_api.authenticate(api_id="1090", api_key="0YW7*IlDQeNE#b#qEHsgcJQbm)lJr@_n)-F")
#
# File ~/lecodage/telq/python_sdk/telq/__init__.py:136, in TelQTelecomAPI.authenticate(self, api_id, api_key)
#     133         self._last_time_authenticated = dt.datetime.now()
#     134 except AttributeError:
#     135     # if the user has never been authenticated
# --> 136     self._authenticated = authentication.Authentication(
#     137         api_id=api_id, api_key=api_key, api_version=self.api_version
#     138     )
#     139     self._last_time_authenticated = dt.datetime.now()
#
# File <string>:6, in __init__(self, api_id, api_key, api_version)
#
# File ~/lecodage/telq/python_sdk/telq/authentication/__init__.py:44, in Authentication.__post_init__(self)
#      42 self.data = {"appId": self.api_id, "appKey": self.api_key}
#      43 self._validate_api_version()
# ---> 44 self._authenticate_user()
#
# File ~/lecodage/telq/python_sdk/telq/authentication/__init__.py:71, in Authentication._authenticate_user(self)
#      69     response.raise_for_status()
#      70 except requests.exceptions.HTTPError as e:
# ---> 71     raise Exception(e)
#      73 json_obj = response.json()
#      74 self._bearer_token = json_obj["value"]
#
# Exception: 403 Client Error: Forbidden for url: https://api.telqtele.com/v2.1/client/token

# %% [markdown]
# ## Retrieve available networks

# %%
telq_api.get_networks()
# Out:
# [{'mcc': '350',
#   'countryName': 'Bermuda',
#   'mnc': '01',
#   'providerName': 'Digicel',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '310',
#   'countryName': 'United States of America',
#   'mnc': '012',
#   'providerName': 'Verizon',
#   'portedFromMnc': '260',
#   'portedFromProviderName': 'T-Mobile'},
#  {'mcc': '238',
#   'countryName': 'Denmark',
#   'mnc': '01',
#   'providerName': 'TDC',
#   'portedFromMnc': '06',
#   'portedFromProviderName': '3'},
#  {'mcc': '231',
#   'countryName': 'Slovakia',
#   'mnc': '02',
#   'providerName': 'Telekom',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '401',
#   'countryName': 'Kazakhstan',
#   'mnc': '02',
#   'providerName': 'Kcell',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '338',
#   'countryName': 'Jamaica',
#   'mnc': '180',
#   'providerName': 'FLOW',
#   'portedFromMnc': '020',
#   'portedFromProviderName': 'FLOW'},
#  {'mcc': '214',
#   'countryName': 'Spain',
#   'mnc': '01',
#   'providerName': 'Vodafone',
#   'portedFromMnc': '06',
#   'portedFromProviderName': 'Vodafone (MVNO)'},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '88',
#   'providerName': 'Wind',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '424',
#   'countryName': 'United Arab Emirates',
#   'mnc': '02',
#   'providerName': 'Etisalat',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '404',
#   'countryName': 'India',
#   'mnc': '31',
#   'providerName': 'Airtel (Ko)',
#   'portedFromMnc': '45',
#   'portedFromProviderName': 'Airtel (Ka)'},
#  {'mcc': '246',
#   'countryName': 'Lithuania',
#   'mnc': '03',
#   'providerName': 'Tele2',
#   'portedFromMnc': '02',
#   'portedFromProviderName': 'BITE'},
#  {'mcc': '364',
#   'countryName': 'Bahamas',
#   'mnc': '49',
#   'providerName': 'Aliv',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '36',
#   'providerName': 'Digi Mobil (MVNO)',
#   'portedFromMnc': '88',
#   'portedFromProviderName': 'Wind'},
#  {'mcc': '724',
#   'countryName': 'Brazil',
#   'mnc': '17',
#   'providerName': 'Correios (MVNO)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '520',
#   'countryName': 'Thailand',
#   'mnc': '00',
#   'providerName': 'CAT Telecom',
#   'portedFromMnc': '15',
#   'portedFromProviderName': 'TOT Mobile'},
#  {'mcc': '724',
#   'countryName': 'Brazil',
#   'mnc': '02',
#   'providerName': 'TIM',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '425',
#   'countryName': 'Israel',
#   'mnc': '06',
#   'providerName': 'Wataniya',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '202',
#   'countryName': 'Greece',
#   'mnc': '01',
#   'providerName': 'Cosmote',
#   'portedFromMnc': '05',
#   'portedFromProviderName': 'Vodafone'},
#  {'mcc': '427',
#   'countryName': 'Qatar',
#   'mnc': '02',
#   'providerName': 'Vodafone',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Ooredoo'},
#  {'mcc': '466',
#   'countryName': 'Taiwan',
#   'mnc': '05',
#   'providerName': 'APTG',
#   'portedFromMnc': '97',
#   'portedFromProviderName': 'Taiwan Mobile'},
#  {'mcc': '274',
#   'countryName': 'Iceland',
#   'mnc': '04',
#   'providerName': 'Viking',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '414',
#   'countryName': 'Myanmar',
#   'mnc': '06',
#   'providerName': 'Telenor',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '416',
#   'countryName': 'Jordan',
#   'mnc': '01',
#   'providerName': 'Zain',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '425',
#   'countryName': 'Israel',
#   'mnc': '19',
#   'providerName': '019 Mobile (MVNO)',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Orange'},
#  {'mcc': '405',
#   'countryName': 'India',
#   'mnc': '858',
#   'providerName': 'Jio (H)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '405',
#   'countryName': 'India',
#   'mnc': '66',
#   'providerName': 'Vi (UPW)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '231',
#   'countryName': 'Slovakia',
#   'mnc': '06',
#   'providerName': 'O2',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Orange'},
#  {'mcc': '706',
#   'countryName': 'El Salvador',
#   'mnc': '01',
#   'providerName': 'Claro',
#   'portedFromMnc': '03',
#   'portedFromProviderName': 'Tigo'},
#  {'mcc': '405',
#   'countryName': 'India',
#   'mnc': '862',
#   'providerName': 'Jio (Ke)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '238',
#   'countryName': 'Denmark',
#   'mnc': '02',
#   'providerName': 'Telenor',
#   'portedFromMnc': '20',
#   'portedFromProviderName': 'Telia'},
#  {'mcc': '732',
#   'countryName': 'Colombia',
#   'mnc': '360',
#   'providerName': 'WOM',
#   'portedFromMnc': '101',
#   'portedFromProviderName': 'Claro'},
#  {'mcc': '208',
#   'countryName': 'France',
#   'mnc': '10',
#   'providerName': 'SFR',
#   'portedFromMnc': '20',
#   'portedFromProviderName': 'Bouygues'},
#  {'mcc': '204',
#   'countryName': 'Netherlands',
#   'mnc': '16',
#   'providerName': 'T-Mobile',
#   'portedFromMnc': '08',
#   'portedFromProviderName': 'KPN'},
#  {'mcc': '744',
#   'countryName': 'Paraguay',
#   'mnc': '02',
#   'providerName': 'Claro',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'VOX'},
#  {'mcc': '730',
#   'countryName': 'Chile',
#   'mnc': '09',
#   'providerName': 'WOM',
#   'portedFromMnc': '02',
#   'portedFromProviderName': 'Movistar'},
#  {'mcc': '214',
#   'countryName': 'Spain',
#   'mnc': '04',
#   'providerName': 'Yoigo',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '610',
#   'countryName': 'Mali',
#   'mnc': '02',
#   'providerName': 'Orange',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '35',
#   'providerName': 'Lycamobile (MVNO)',
#   'portedFromMnc': '10',
#   'portedFromProviderName': 'Vodafone'},
#  {'mcc': '732',
#   'countryName': 'Colombia',
#   'mnc': '154',
#   'providerName': 'Virgin Mobile (MVNO)',
#   'portedFromMnc': '111',
#   'portedFromProviderName': 'Tigo'},
#  {'mcc': '260',
#   'countryName': 'Poland',
#   'mnc': '01',
#   'providerName': 'Plus',
#   'portedFromMnc': '02',
#   'portedFromProviderName': 'T-mobile'},
#  {'mcc': '425',
#   'countryName': 'Israel',
#   'mnc': '07',
#   'providerName': 'Hot Mobile',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Orange'},
#  {'mcc': '208',
#   'countryName': 'France',
#   'mnc': '26',
#   'providerName': 'NRJ Mobile (MVNO)',
#   'portedFromMnc': '10',
#   'portedFromProviderName': 'SFR'},
#  {'mcc': '404',
#   'countryName': 'India',
#   'mnc': '92',
#   'providerName': 'Airtel (Mu)',
#   'portedFromMnc': '20',
#   'portedFromProviderName': 'Vi (Mu)'},
#  {'mcc': '615',
#   'countryName': 'Togo',
#   'mnc': '01',
#   'providerName': 'Togo Cell',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '272',
#   'countryName': 'Ireland',
#   'mnc': '01',
#   'providerName': 'Vodafone',
#   'portedFromMnc': '03',
#   'portedFromProviderName': 'Meteor'},
#  {'mcc': '520',
#   'countryName': 'Thailand',
#   'mnc': '03',
#   'providerName': 'AIS',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '744',
#   'countryName': 'Paraguay',
#   'mnc': '02',
#   'providerName': 'Claro',
#   'portedFromMnc': '04',
#   'portedFromProviderName': 'Tigo'},
#  {'mcc': '425',
#   'countryName': 'Israel',
#   'mnc': '08',
#   'providerName': 'Golan Telecom',
#   'portedFromMnc': '03',
#   'portedFromProviderName': 'Pelephone'},
#  {'mcc': '250',
#   'countryName': 'Russian Federation',
#   'mnc': '20',
#   'providerName': 'Tele2',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '744',
#   'countryName': 'Paraguay',
#   'mnc': '05',
#   'providerName': 'Personal',
#   'portedFromMnc': '02',
#   'portedFromProviderName': 'Claro'},
#  {'mcc': '219',
#   'countryName': 'Croatia',
#   'mnc': '02',
#   'providerName': 'Tele2',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'T-Mobile'},
#  {'mcc': '452',
#   'countryName': 'Vietnam',
#   'mnc': '04',
#   'providerName': 'Viettel',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '457',
#   'countryName': 'Laos',
#   'mnc': '03',
#   'providerName': 'Unitel',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '208',
#   'countryName': 'France',
#   'mnc': '01',
#   'providerName': 'Orange',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '268',
#   'countryName': 'Portugal',
#   'mnc': '06',
#   'providerName': 'MEO',
#   'portedFromMnc': '03',
#   'portedFromProviderName': 'NOS'},
#  {'mcc': '604',
#   'countryName': 'Morocco',
#   'mnc': '02',
#   'providerName': 'INWI',
#   'portedFromMnc': '00',
#   'portedFromProviderName': 'Meditel'},
#  {'mcc': '400',
#   'countryName': 'Azerbaijan',
#   'mnc': '02',
#   'providerName': 'Bakcell',
#   'portedFromMnc': '04',
#   'portedFromProviderName': 'Nar Mobile'},
#  {'mcc': '714',
#   'countryName': 'Panama',
#   'mnc': '04',
#   'providerName': 'Digicel',
#   'portedFromMnc': '03',
#   'portedFromProviderName': 'Claro'},
#  {'mcc': '730',
#   'countryName': 'Chile',
#   'mnc': '01',
#   'providerName': 'Entel',
#   'portedFromMnc': '02',
#   'portedFromProviderName': 'Movistar'},
#  {'mcc': '414',
#   'countryName': 'Myanmar',
#   'mnc': '09',
#   'providerName': 'Mytel',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '744',
#   'countryName': 'Paraguay',
#   'mnc': '04',
#   'providerName': 'Tigo',
#   'portedFromMnc': '05',
#   'portedFromProviderName': 'Personal'},
#  {'mcc': '310',
#   'countryName': 'United States of America',
#   'mnc': '150',
#   'providerName': 'AT&T',
#   'portedFromMnc': '260',
#   'portedFromProviderName': 'T-Mobile'},
#  {'mcc': '214',
#   'countryName': 'Spain',
#   'mnc': '03',
#   'providerName': 'Orange',
#   'portedFromMnc': '04',
#   'portedFromProviderName': 'Yoigo'},
#  {'mcc': '730',
#   'countryName': 'Chile',
#   'mnc': '09',
#   'providerName': 'WOM',
#   'portedFromMnc': '19',
#   'portedFromProviderName': 'Falabella (MVNO)'},
#  {'mcc': '611',
#   'countryName': 'Guinea',
#   'mnc': '04',
#   'providerName': 'MTN',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '502',
#   'countryName': 'Malaysia',
#   'mnc': '153',
#   'providerName': 'Webe',
#   'portedFromMnc': '150',
#   'portedFromProviderName': 'Tune Talk (MVNO)'},
#  {'mcc': '724',
#   'countryName': 'Brazil',
#   'mnc': '15',
#   'providerName': 'Sercomtel',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '605',
#   'countryName': 'Tunisia',
#   'mnc': '02',
#   'providerName': 'Tunicell',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Orange'},
#  {'mcc': '425',
#   'countryName': 'Israel',
#   'mnc': '05',
#   'providerName': 'Jawwal',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '208',
#   'countryName': 'France',
#   'mnc': '10',
#   'providerName': 'SFR',
#   'portedFromMnc': '25',
#   'portedFromProviderName': 'Lycamobile (MVNO)'},
#  {'mcc': '214',
#   'countryName': 'Spain',
#   'mnc': '03',
#   'providerName': 'Orange',
#   'portedFromMnc': '17',
#   'portedFromProviderName': 'Mobil R (MVNO)'},
#  {'mcc': '736',
#   'countryName': 'Bolivia',
#   'mnc': '03',
#   'providerName': 'Tigo',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '206',
#   'countryName': 'Belgium',
#   'mnc': '30',
#   'providerName': 'Mobile Vikings (MVNO)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '744',
#   'countryName': 'Paraguay',
#   'mnc': '04',
#   'providerName': 'Tigo',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'VOX'},
#  {'mcc': '426',
#   'countryName': 'Bahrain',
#   'mnc': '02',
#   'providerName': 'Zain',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Batelco'},
#  {'mcc': '706',
#   'countryName': 'El Salvador',
#   'mnc': '04',
#   'providerName': 'Movistar',
#   'portedFromMnc': '02',
#   'portedFromProviderName': 'Digicel'},
#  {'mcc': '425',
#   'countryName': 'Israel',
#   'mnc': '01',
#   'providerName': 'Orange',
#   'portedFromMnc': '02',
#   'portedFromProviderName': 'Cellcom'},
#  {'mcc': '605',
#   'countryName': 'Tunisia',
#   'mnc': '01',
#   'providerName': 'Orange',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '214',
#   'countryName': 'Spain',
#   'mnc': '22',
#   'providerName': 'DigiMobil (MVNO)',
#   'portedFromMnc': '06',
#   'portedFromProviderName': 'Vodafone (MVNO)'},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '33',
#   'providerName': 'Poste Mobile (MVNO)',
#   'portedFromMnc': '50',
#   'portedFromProviderName': 'Iliad'},
#  {'mcc': '246',
#   'countryName': 'Lithuania',
#   'mnc': '02',
#   'providerName': 'BITE',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Telia'},
#  {'mcc': '628',
#   'countryName': 'Gabon',
#   'mnc': '03',
#   'providerName': 'Airtel',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '244',
#   'countryName': 'Finland',
#   'mnc': '91',
#   'providerName': 'Sonera',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '272',
#   'countryName': 'Ireland',
#   'mnc': '11',
#   'providerName': 'Tesco Mobile (MVNO)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '232',
#   'countryName': 'Austria',
#   'mnc': '05',
#   'providerName': '3',
#   'portedFromMnc': '03',
#   'portedFromProviderName': 'Magenta'},
#  {'mcc': '510',
#   'countryName': 'Indonesia',
#   'mnc': '11',
#   'providerName': 'XL',
#   'portedFromMnc': '08',
#   'portedFromProviderName': 'AXIS'},
#  {'mcc': '262',
#   'countryName': 'Germany',
#   'mnc': '01',
#   'providerName': 'T-Mobile',
#   'portedFromMnc': '02',
#   'portedFromProviderName': 'Vodafone'},
#  {'mcc': '466',
#   'countryName': 'Taiwan',
#   'mnc': '01',
#   'providerName': 'FarEasTone',
#   'portedFromMnc': '97',
#   'portedFromProviderName': 'Taiwan Mobile'},
#  {'mcc': '740',
#   'countryName': 'Ecuador',
#   'mnc': '01',
#   'providerName': 'Claro',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '404',
#   'countryName': 'India',
#   'mnc': '54',
#   'providerName': 'BSNL Mobile (UPW)',
#   'portedFromMnc': '74',
#   'portedFromProviderName': 'BSNL Mobile (WB)'},
#  {'mcc': '404',
#   'countryName': 'India',
#   'mnc': '94',
#   'providerName': 'Airtel (TN)',
#   'portedFromMnc': '41',
#   'portedFromProviderName': 'Aircel (C)'},
#  {'mcc': '405',
#   'countryName': 'India',
#   'mnc': '865',
#   'providerName': 'Jio (NE)',
#   'portedFromMnc': '755',
#   'portedFromProviderName': 'Vi (NE)'},
#  {'mcc': '724',
#   'countryName': 'Brazil',
#   'mnc': '16',
#   'providerName': 'Oi',
#   'portedFromMnc': '05',
#   'portedFromProviderName': 'Claro'},
#  {'mcc': '232',
#   'countryName': 'Austria',
#   'mnc': '19',
#   'providerName': 'Hutchinson Drei',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '502',
#   'countryName': 'Malaysia',
#   'mnc': '18',
#   'providerName': 'U Mobile',
#   'portedFromMnc': '16',
#   'portedFromProviderName': 'DiGi'},
#  {'mcc': '708',
#   'countryName': 'Honduras',
#   'mnc': '001',
#   'providerName': 'Claro',
#   'portedFromMnc': '002',
#   'portedFromProviderName': 'Tigo'},
#  {'mcc': '226',
#   'countryName': 'Romania',
#   'mnc': '05',
#   'providerName': 'Digi Mobil',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '268',
#   'countryName': 'Portugal',
#   'mnc': '03',
#   'providerName': 'NOS',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '425',
#   'countryName': 'Israel',
#   'mnc': '03',
#   'providerName': 'Pelephone',
#   'portedFromMnc': '07',
#   'portedFromProviderName': 'Hot Mobile'},
#  {'mcc': '226',
#   'countryName': 'Romania',
#   'mnc': '03',
#   'providerName': 'Telekom',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '234',
#   'countryName': 'United Kingdom',
#   'mnc': '15',
#   'providerName': 'Vodafone',
#   'portedFromMnc': '10',
#   'portedFromProviderName': 'O2'},
#  {'mcc': '278',
#   'countryName': 'Malta',
#   'mnc': '01',
#   'providerName': 'Vodafone',
#   'portedFromMnc': '21',
#   'portedFromProviderName': 'GO'},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '99',
#   'providerName': '3',
#   'portedFromMnc': '88',
#   'portedFromProviderName': 'Wind'},
#  {'mcc': '614',
#   'countryName': 'Niger',
#   'mnc': '02',
#   'providerName': 'Airtel',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '278',
#   'countryName': 'Malta',
#   'mnc': '77',
#   'providerName': 'Melita',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Vodafone'},
#  {'mcc': '457',
#   'countryName': 'Laos',
#   'mnc': '01',
#   'providerName': 'LTC',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '08',
#   'providerName': 'Fastweb (MVNO)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '401',
#   'countryName': 'Kazakhstan',
#   'mnc': '07',
#   'providerName': 'Altel',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '234',
#   'countryName': 'United Kingdom',
#   'mnc': '57',
#   'providerName': 'Sky UK',
#   'portedFromMnc': '10',
#   'portedFromProviderName': 'O2'},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '08',
#   'providerName': 'Fastweb (MVNO)',
#   'portedFromMnc': '88',
#   'portedFromProviderName': 'Wind'},
#  {'mcc': '226',
#   'countryName': 'Romania',
#   'mnc': '01',
#   'providerName': 'Vodafone',
#   'portedFromMnc': '10',
#   'portedFromProviderName': 'Orange'},
#  {'mcc': '410',
#   'countryName': 'Pakistan',
#   'mnc': '04',
#   'providerName': 'Zong',
#   'portedFromMnc': '06',
#   'portedFromProviderName': 'Telenor'},
#  {'mcc': '530',
#   'countryName': 'New Zealand',
#   'mnc': '01',
#   'providerName': 'Vodafone',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '732',
#   'countryName': 'Colombia',
#   'mnc': '240',
#   'providerName': 'Logistica Flash',
#   'portedFromMnc': '101',
#   'portedFromProviderName': 'Claro'},
#  {'mcc': '242',
#   'countryName': 'Norway',
#   'mnc': '23',
#   'providerName': 'Lycamobile (MVNO)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '334',
#   'countryName': 'Mexico',
#   'mnc': '020',
#   'providerName': 'Telcel',
#   'portedFromMnc': '030',
#   'portedFromProviderName': 'Movistar (MVNO)'},
#  {'mcc': '293',
#   'countryName': 'Slovenia',
#   'mnc': '41',
#   'providerName': 'Mobitel',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '732',
#   'countryName': 'Colombia',
#   'mnc': '360',
#   'providerName': 'WOM',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '366',
#   'countryName': 'Dominica',
#   'mnc': '020',
#   'providerName': 'Digicel',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '342',
#   'countryName': 'Barbados',
#   'mnc': '750',
#   'providerName': 'Digicel',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '706',
#   'countryName': 'El Salvador',
#   'mnc': '03',
#   'providerName': 'Tigo',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Claro'},
#  {'mcc': '547',
#   'countryName': 'French Polynesia',
#   'mnc': '20',
#   'providerName': 'Vini',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '425',
#   'countryName': 'Israel',
#   'mnc': '02',
#   'providerName': 'Cellcom',
#   'portedFromMnc': '07',
#   'portedFromProviderName': 'Hot Mobile'},
#  {'mcc': '404',
#   'countryName': 'India',
#   'mnc': '49',
#   'providerName': 'Airtel (AP&T)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '630',
#   'countryName': 'DR Congo',
#   'mnc': '90',
#   'providerName': 'Africell',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '652',
#   'countryName': 'Botswana',
#   'mnc': '01',
#   'providerName': 'Mascom',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '419',
#   'countryName': 'Kuwait',
#   'mnc': '04',
#   'providerName': 'Viva',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '53',
#   'providerName': 'COOP Voce (MVNO)',
#   'portedFromMnc': '99',
#   'portedFromProviderName': '3'},
#  {'mcc': '732',
#   'countryName': 'Colombia',
#   'mnc': '123',
#   'providerName': 'Movistar',
#   'portedFromMnc': '103',
#   'portedFromProviderName': 'Tigo'},
#  {'mcc': '410',
#   'countryName': 'Pakistan',
#   'mnc': '04',
#   'providerName': 'Zong',
#   'portedFromMnc': '08',
#   'portedFromProviderName': 'SCO Mobile'},
#  {'mcc': '405',
#   'countryName': 'India',
#   'mnc': '67',
#   'providerName': 'Vi (WB)',
#   'portedFromMnc': '51',
#   'portedFromProviderName': 'Airtel (WB)'},
#  {'mcc': '228',
#   'countryName': 'Switzerland',
#   'mnc': '54',
#   'providerName': 'Lycamobile (MVNO)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '50',
#   'providerName': 'Iliad',
#   'portedFromMnc': '88',
#   'portedFromProviderName': 'Wind'},
#  {'mcc': '260',
#   'countryName': 'Poland',
#   'mnc': '03',
#   'providerName': 'Orange',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Plus'},
#  {'mcc': '234',
#   'countryName': 'United Kingdom',
#   'mnc': '50',
#   'providerName': 'JT-Wave',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '356',
#   'countryName': 'Saint Kitts and Nevis',
#   'mnc': '110',
#   'providerName': 'LIME',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '502',
#   'countryName': 'Malaysia',
#   'mnc': '195',
#   'providerName': 'XOX Com',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '732',
#   'countryName': 'Colombia',
#   'mnc': '123',
#   'providerName': 'Movistar',
#   'portedFromMnc': '111',
#   'portedFromProviderName': 'Tigo'},
#  {'mcc': '206',
#   'countryName': 'Belgium',
#   'mnc': '05',
#   'providerName': 'Telenet (MVNO)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '250',
#   'countryName': 'Russian Federation',
#   'mnc': '35',
#   'providerName': 'Motiv',
#   'portedFromMnc': '99',
#   'portedFromProviderName': 'Beeline'},
#  {'mcc': '420',
#   'countryName': 'Saudi Arabia',
#   'mnc': '01',
#   'providerName': 'Al Jawal',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '454',
#   'countryName': 'Hong Kong',
#   'mnc': '00',
#   'providerName': 'CSL',
#   'portedFromMnc': '12',
#   'portedFromProviderName': 'CMCC HK'},
#  {'mcc': '466',
#   'countryName': 'Taiwan',
#   'mnc': '05',
#   'providerName': 'APTG',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '412',
#   'countryName': 'Afghanistan',
#   'mnc': '88',
#   'providerName': 'Afghan Telecom',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '452',
#   'countryName': 'Vietnam',
#   'mnc': '04',
#   'providerName': 'Viettel',
#   'portedFromMnc': '05',
#   'portedFromProviderName': 'Vietnamobile'},
#  {'mcc': '284',
#   'countryName': 'Bulgaria',
#   'mnc': '03',
#   'providerName': 'Vivacom',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '234',
#   'countryName': 'United Kingdom',
#   'mnc': '10',
#   'providerName': 'O2',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '706',
#   'countryName': 'El Salvador',
#   'mnc': '04',
#   'providerName': 'Movistar',
#   'portedFromMnc': '03',
#   'portedFromProviderName': 'Tigo'},
#  {'mcc': '214',
#   'countryName': 'Spain',
#   'mnc': '16',
#   'providerName': 'TeleCable (MVNO)',
#   'portedFromMnc': '04',
#   'portedFromProviderName': 'Yoigo'},
#  {'mcc': '404',
#   'countryName': 'India',
#   'mnc': '49',
#   'providerName': 'Airtel (AP&T)',
#   'portedFromMnc': '07',
#   'portedFromProviderName': 'Vi (AP&T)'},
#  {'mcc': '250',
#   'countryName': 'Russian Federation',
#   'mnc': '02',
#   'providerName': 'Megafon',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'MTS'},
#  {'mcc': '732',
#   'countryName': 'Colombia',
#   'mnc': '360',
#   'providerName': 'WOM',
#   'portedFromMnc': '240',
#   'portedFromProviderName': 'Logistica Flash'},
#  {'mcc': '732',
#   'countryName': 'Colombia',
#   'mnc': '154',
#   'providerName': 'Virgin Mobile (MVNO)',
#   'portedFromMnc': '101',
#   'portedFromProviderName': 'Claro'},
#  {'mcc': '604',
#   'countryName': 'Morocco',
#   'mnc': '01',
#   'providerName': 'IAM',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '405',
#   'countryName': 'India',
#   'mnc': '874',
#   'providerName': 'Jio (Mu)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '302',
#   'countryName': 'Canada',
#   'mnc': '720',
#   'providerName': 'Rogers Wireless',
#   'portedFromMnc': '660',
#   'portedFromProviderName': 'MTS'},
#  {'mcc': '214',
#   'countryName': 'Spain',
#   'mnc': '16',
#   'providerName': 'TeleCable (MVNO)',
#   'portedFromMnc': '17',
#   'portedFromProviderName': 'Mobil R (MVNO)'},
#  {'mcc': '621',
#   'countryName': 'Nigeria',
#   'mnc': '30',
#   'providerName': 'MTN',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '454',
#   'countryName': 'Hong Kong',
#   'mnc': '03',
#   'providerName': '3',
#   'portedFromMnc': '09',
#   'portedFromProviderName': 'China Motion (MVNO)'},
#  {'mcc': '530',
#   'countryName': 'New Zealand',
#   'mnc': '01',
#   'providerName': 'Vodafone',
#   'portedFromMnc': '05',
#   'portedFromProviderName': 'Spark'},
#  {'mcc': '250',
#   'countryName': 'Russian Federation',
#   'mnc': '99',
#   'providerName': 'Beeline',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '282',
#   'countryName': 'Georgia',
#   'mnc': '01',
#   'providerName': 'Geocell',
#   'portedFromMnc': '04',
#   'portedFromProviderName': 'Beeline'},
#  {'mcc': '242',
#   'countryName': 'Norway',
#   'mnc': '14',
#   'providerName': 'ICE',
#   'portedFromMnc': '02',
#   'portedFromProviderName': 'NetCom'},
#  {'mcc': '214',
#   'countryName': 'Spain',
#   'mnc': '19',
#   'providerName': 'Simyo (MVNO)',
#   'portedFromMnc': '04',
#   'portedFromProviderName': 'Yoigo'},
#  {'mcc': '204',
#   'countryName': 'Netherlands',
#   'mnc': '09',
#   'providerName': 'Lycamobile (MVNO)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '278',
#   'countryName': 'Malta',
#   'mnc': '21',
#   'providerName': 'GO',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Vodafone'},
#  {'mcc': '248',
#   'countryName': 'Estonia',
#   'mnc': '03',
#   'providerName': 'Tele2',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '240',
#   'countryName': 'Sweden',
#   'mnc': '08',
#   'providerName': 'Telenor',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '208',
#   'countryName': 'France',
#   'mnc': '15',
#   'providerName': 'Free Mobile',
#   'portedFromMnc': '27',
#   'portedFromProviderName': 'Coriolis (MVNO)'},
#  {'mcc': '302',
#   'countryName': 'Canada',
#   'mnc': '610',
#   'providerName': 'Bell Mobility',
#   'portedFromMnc': '220',
#   'portedFromProviderName': 'Telus Mobility'},
#  {'mcc': '362',
#   'countryName': 'Curacao and the Caribbean Netherlands',
#   'mnc': '91',
#   'providerName': 'UTS',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '208',
#   'countryName': 'France',
#   'mnc': '26',
#   'providerName': 'NRJ Mobile (MVNO)',
#   'portedFromMnc': '15',
#   'portedFromProviderName': 'Free Mobile'},
#  {'mcc': '257',
#   'countryName': 'Belarus',
#   'mnc': '02',
#   'providerName': 'MTS',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Velcom'},
#  {'mcc': '360',
#   'countryName': 'Saint Vincent and the Grenadines',
#   'mnc': '110',
#   'providerName': 'LIME',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '260',
#   'countryName': 'Poland',
#   'mnc': '06',
#   'providerName': 'Play',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '520',
#   'countryName': 'Thailand',
#   'mnc': '03',
#   'providerName': 'AIS',
#   'portedFromMnc': '00',
#   'portedFromProviderName': 'CAT Telecom'},
#  {'mcc': '334',
#   'countryName': 'Mexico',
#   'mnc': '140',
#   'providerName': 'Altan Redes',
#   'portedFromMnc': '020',
#   'portedFromProviderName': 'Telcel'},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '07',
#   'providerName': 'Noverca (MVNO)',
#   'portedFromMnc': '88',
#   'portedFromProviderName': 'Wind'},
#  {'mcc': '716',
#   'countryName': 'Peru',
#   'mnc': '10',
#   'providerName': 'Claro',
#   'portedFromMnc': '17',
#   'portedFromProviderName': 'Entel'},
#  {'mcc': '226',
#   'countryName': 'Romania',
#   'mnc': '05',
#   'providerName': 'Digi Mobil',
#   'portedFromMnc': '03',
#   'portedFromProviderName': 'Telekom'},
#  {'mcc': '232',
#   'countryName': 'Austria',
#   'mnc': '01',
#   'providerName': 'A1',
#   'portedFromMnc': '05',
#   'portedFromProviderName': '3'},
#  {'mcc': '293',
#   'countryName': 'Slovenia',
#   'mnc': '41',
#   'providerName': 'Mobitel',
#   'portedFromMnc': '70',
#   'portedFromProviderName': 'Tusmobil'},
#  {'mcc': '648',
#   'countryName': 'Zimbabwe',
#   'mnc': '01',
#   'providerName': 'NetOne',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '08',
#   'providerName': 'Fastweb (MVNO)',
#   'portedFromMnc': '50',
#   'portedFromProviderName': 'Iliad'},
#  {'mcc': '425',
#   'countryName': 'Israel',
#   'mnc': '08',
#   'providerName': 'Golan Telecom',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Orange'},
#  {'mcc': '214',
#   'countryName': 'Spain',
#   'mnc': '03',
#   'providerName': 'Orange',
#   'portedFromMnc': '06',
#   'portedFromProviderName': 'Vodafone (MVNO)'},
#  {'mcc': '232',
#   'countryName': 'Austria',
#   'mnc': '03',
#   'providerName': 'Magenta',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '33',
#   'providerName': 'Poste Mobile (MVNO)',
#   'portedFromMnc': '88',
#   'portedFromProviderName': 'Wind'},
#  {'mcc': '334',
#   'countryName': 'Mexico',
#   'mnc': '050',
#   'providerName': 'AT&T, Unefon',
#   'portedFromMnc': '070',
#   'portedFromProviderName': 'Unefon'},
#  {'mcc': '736',
#   'countryName': 'Bolivia',
#   'mnc': '02',
#   'providerName': 'Entel',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Viva'},
#  {'mcc': '454',
#   'countryName': 'Hong Kong',
#   'mnc': '24',
#   'providerName': 'Multibyte (MVNO)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '07',
#   'providerName': 'Noverca (MVNO)',
#   'portedFromMnc': '35',
#   'portedFromProviderName': 'Lycamobile (MVNO)'},
#  {'mcc': '334',
#   'countryName': 'Mexico',
#   'mnc': '090',
#   'providerName': 'AT&T',
#   'portedFromMnc': '020',
#   'portedFromProviderName': 'Telcel'},
#  {'mcc': '542',
#   'countryName': 'Fiji',
#   'mnc': '01',
#   'providerName': 'Vodafone',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '255',
#   'countryName': 'Ukraine',
#   'mnc': '07',
#   'providerName': '3Mob',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '302',
#   'countryName': 'Canada',
#   'mnc': '370',
#   'providerName': 'Fido (MVNO)',
#   'portedFromMnc': '220',
#   'portedFromProviderName': 'Telus Mobility'},
#  {'mcc': '432',
#   'countryName': 'Iran',
#   'mnc': '01',
#   'providerName': 'Samantel',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '470',
#   'countryName': 'Bangladesh',
#   'mnc': '02',
#   'providerName': 'Airtel',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'GrameenPhone'},
#  {'mcc': '602',
#   'countryName': 'Egypt',
#   'mnc': '03',
#   'providerName': 'Etisalat',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Orange'},
#  {'mcc': '216',
#   'countryName': 'Hungary',
#   'mnc': '70',
#   'providerName': 'Vodafone',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '208',
#   'countryName': 'France',
#   'mnc': '20',
#   'providerName': 'Bouygues',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Orange'},
#  {'mcc': '525',
#   'countryName': 'Singapore',
#   'mnc': '03',
#   'providerName': 'M1',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '724',
#   'countryName': 'Brazil',
#   'mnc': '06',
#   'providerName': 'Vivo',
#   'portedFromMnc': '05',
#   'portedFromProviderName': 'Claro'},
#  {'mcc': '438',
#   'countryName': 'Turkmenistan',
#   'mnc': '02',
#   'providerName': 'TM-Cell',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '208',
#   'countryName': 'France',
#   'mnc': '27',
#   'providerName': 'Coriolis (MVNO)',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Orange'},
#  {'mcc': '234',
#   'countryName': 'United Kingdom',
#   'mnc': '57',
#   'providerName': 'Sky UK',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '730',
#   'countryName': 'Chile',
#   'mnc': '01',
#   'providerName': 'Entel',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '234',
#   'countryName': 'United Kingdom',
#   'mnc': '15',
#   'providerName': 'Vodafone',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '284',
#   'countryName': 'Bulgaria',
#   'mnc': '01',
#   'providerName': 'A1',
#   'portedFromMnc': '03',
#   'portedFromProviderName': 'Vivacom'},
#  {'mcc': '204',
#   'countryName': 'Netherlands',
#   'mnc': '04',
#   'providerName': 'Vodafone',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '280',
#   'countryName': 'Cyprus',
#   'mnc': '10',
#   'providerName': 'MTN',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '302',
#   'countryName': 'Canada',
#   'mnc': '490',
#   'providerName': 'Freedom Mobile',
#   'portedFromMnc': '610',
#   'portedFromProviderName': 'Bell Mobility'},
#  {'mcc': '259',
#   'countryName': 'Moldova',
#   'mnc': '05',
#   'providerName': 'Unite',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '231',
#   'countryName': 'Slovakia',
#   'mnc': '03',
#   'providerName': 'Swan',
#   'portedFromMnc': '06',
#   'portedFromProviderName': 'O2'},
#  {'mcc': '208',
#   'countryName': 'France',
#   'mnc': '20',
#   'providerName': 'Bouygues',
#   'portedFromMnc': '26',
#   'portedFromProviderName': 'NRJ Mobile (MVNO)'},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '01',
#   'providerName': 'TIM',
#   'portedFromMnc': '53',
#   'portedFromProviderName': 'COOP Voce (MVNO)'},
#  {'mcc': '208',
#   'countryName': 'France',
#   'mnc': '10',
#   'providerName': 'SFR',
#   'portedFromMnc': '26',
#   'portedFromProviderName': 'NRJ Mobile (MVNO)'},
#  {'mcc': '716',
#   'countryName': 'Peru',
#   'mnc': '06',
#   'providerName': 'Movistar',
#   'portedFromMnc': '10',
#   'portedFromProviderName': 'Claro'},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '35',
#   'providerName': 'Lycamobile (MVNO)',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'TIM'},
#  {'mcc': '260',
#   'countryName': 'Poland',
#   'mnc': '02',
#   'providerName': 'T-mobile',
#   'portedFromMnc': '03',
#   'portedFromProviderName': 'Orange'},
#  {'mcc': '740',
#   'countryName': 'Ecuador',
#   'mnc': '02',
#   'providerName': 'CNT Mobile',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '344',
#   'countryName': 'Antigua and Barbuda',
#   'mnc': '030',
#   'providerName': 'APUA',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '732',
#   'countryName': 'Colombia',
#   'mnc': '123',
#   'providerName': 'Movistar',
#   'portedFromMnc': '360',
#   'portedFromProviderName': 'WOM'},
#  {'mcc': '732',
#   'countryName': 'Colombia',
#   'mnc': '111',
#   'providerName': 'Tigo',
#   'portedFromMnc': '101',
#   'portedFromProviderName': 'Claro'},
#  {'mcc': '370',
#   'countryName': 'Dominican Republic',
#   'mnc': '02',
#   'providerName': 'Claro',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '602',
#   'countryName': 'Egypt',
#   'mnc': '02',
#   'providerName': 'Vodafone',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '730',
#   'countryName': 'Chile',
#   'mnc': '13',
#   'providerName': 'Virgin Mobile (MVNO)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '214',
#   'countryName': 'Spain',
#   'mnc': '19',
#   'providerName': 'Simyo (MVNO)',
#   'portedFromMnc': '21',
#   'portedFromProviderName': 'Jazztel (MVNO)'},
#  {'mcc': '502',
#   'countryName': 'Malaysia',
#   'mnc': '153',
#   'providerName': 'Webe',
#   'portedFromMnc': '12',
#   'portedFromProviderName': 'Maxis'},
#  {'mcc': '234',
#   'countryName': 'United Kingdom',
#   'mnc': '15',
#   'providerName': 'Vodafone',
#   'portedFromMnc': '26',
#   'portedFromProviderName': 'Lycamobile (MVNO)'},
#  {'mcc': '724',
#   'countryName': 'Brazil',
#   'mnc': '34',
#   'providerName': 'Algar Telecom',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '639',
#   'countryName': 'Kenya',
#   'mnc': '02',
#   'providerName': 'Safaricom',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '425',
#   'countryName': 'Israel',
#   'mnc': '02',
#   'providerName': 'Cellcom',
#   'portedFromMnc': '03',
#   'portedFromProviderName': 'Pelephone'},
#  {'mcc': '405',
#   'countryName': 'India',
#   'mnc': '54',
#   'providerName': 'Airtel (UPE)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '218',
#   'countryName': 'Bosnia and Herzegovina',
#   'mnc': '90',
#   'providerName': 'BH Mobile',
#   'portedFromMnc': '05',
#   'portedFromProviderName': 'm:tel'},
#  {'mcc': '248',
#   'countryName': 'Estonia',
#   'mnc': '02',
#   'providerName': 'Elisa',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '452',
#   'countryName': 'Vietnam',
#   'mnc': '01',
#   'providerName': 'MobiFone',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '510',
#   'countryName': 'Indonesia',
#   'mnc': '28',
#   'providerName': 'Smartfren',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '616',
#   'countryName': 'Benin',
#   'mnc': '02',
#   'providerName': 'Moov',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '613',
#   'countryName': 'Burkina Faso',
#   'mnc': '03',
#   'providerName': 'Telecel',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '202',
#   'countryName': 'Greece',
#   'mnc': '10',
#   'providerName': 'Wind',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '268',
#   'countryName': 'Portugal',
#   'mnc': '04',
#   'providerName': 'Lycamobile (MVNO)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '01',
#   'providerName': 'TIM',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '422',
#   'countryName': 'Oman',
#   'mnc': '06',
#   'providerName': 'Vodafone',
#   'portedFromMnc': '03',
#   'portedFromProviderName': 'Nawras'},
#  {'mcc': '276',
#   'countryName': 'Albania',
#   'mnc': '01',
#   'providerName': 'AMC',
#   'portedFromMnc': '03',
#   'portedFromProviderName': 'Eagle Mobile'},
#  {'mcc': '218',
#   'countryName': 'Bosnia and Herzegovina',
#   'mnc': '05',
#   'providerName': 'm:tel',
#   'portedFromMnc': '90',
#   'portedFromProviderName': 'BH Mobile'},
#  {'mcc': '230',
#   'countryName': 'Czech Republic',
#   'mnc': '01',
#   'providerName': 'T-Mobile',
#   'portedFromMnc': '02',
#   'portedFromProviderName': 'O2'},
#  {'mcc': '505',
#   'countryName': 'Australia',
#   'mnc': '02',
#   'providerName': 'Optus',
#   'portedFromMnc': '03',
#   'portedFromProviderName': 'Vodafone'},
#  {'mcc': '257',
#   'countryName': 'Belarus',
#   'mnc': '01',
#   'providerName': 'Velcom',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '640',
#   'countryName': 'Tanzania',
#   'mnc': '03',
#   'providerName': 'Zantel',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '724',
#   'countryName': 'Brazil',
#   'mnc': '02',
#   'providerName': 'TIM',
#   'portedFromMnc': '06',
#   'portedFromProviderName': 'Vivo'},
#  {'mcc': '505',
#   'countryName': 'Australia',
#   'mnc': '02',
#   'providerName': 'Optus',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Telstra'},
#  {'mcc': '240',
#   'countryName': 'Sweden',
#   'mnc': '12',
#   'providerName': 'Lycamobile (MVNO)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '410',
#   'countryName': 'Pakistan',
#   'mnc': '03',
#   'providerName': 'Ufone',
#   'portedFromMnc': '06',
#   'portedFromProviderName': 'Telenor'},
#  {'mcc': '466',
#   'countryName': 'Taiwan',
#   'mnc': '92',
#   'providerName': 'Chunghwa',
#   'portedFromMnc': '05',
#   'portedFromProviderName': 'APTG'},
#  {'mcc': '520',
#   'countryName': 'Thailand',
#   'mnc': '15',
#   'providerName': 'TOT Mobile',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '425',
#   'countryName': 'Israel',
#   'mnc': '07',
#   'providerName': 'Hot Mobile',
#   'portedFromMnc': '08',
#   'portedFromProviderName': 'Golan Telecom'},
#  {'mcc': '634',
#   'countryName': 'Sudan',
#   'mnc': '07',
#   'providerName': 'Sudani One',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '272',
#   'countryName': 'Ireland',
#   'mnc': '01',
#   'providerName': 'Vodafone',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '410',
#   'countryName': 'Pakistan',
#   'mnc': '05',
#   'providerName': 'SCO Mobile',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '310',
#   'countryName': 'United States of America',
#   'mnc': '450',
#   'providerName': 'Viaero',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '647',
#   'countryName': 'Reunion and Mayotte',
#   'mnc': '04',
#   'providerName': 'Zeop',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '250',
#   'countryName': 'Russian Federation',
#   'mnc': '11',
#   'providerName': 'Yota (MVNO)',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'MTS'},
#  {'mcc': '460',
#   'countryName': 'China',
#   'mnc': '01',
#   'providerName': 'China Unicom',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '704',
#   'countryName': 'Guatemala',
#   'mnc': '01',
#   'providerName': 'Claro',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '450',
#   'countryName': 'South Korea',
#   'mnc': '08',
#   'providerName': 'olleh',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '425',
#   'countryName': 'Israel',
#   'mnc': '01',
#   'providerName': 'Orange',
#   'portedFromMnc': '07',
#   'portedFromProviderName': 'Hot Mobile'},
#  {'mcc': '436',
#   'countryName': 'Tajikistan',
#   'mnc': '02',
#   'providerName': 'Tcell',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '310',
#   'countryName': 'United States of America',
#   'mnc': '200',
#   'providerName': 'T-Mobile',
#   'portedFromMnc': '150',
#   'portedFromProviderName': 'AT&T'},
#  {'mcc': '440',
#   'countryName': 'Japan',
#   'mnc': '54',
#   'providerName': 'KDDI',
#   'portedFromMnc': '50',
#   'portedFromProviderName': 'KDDI'},
#  {'mcc': '214',
#   'countryName': 'Spain',
#   'mnc': '04',
#   'providerName': 'Yoigo',
#   'portedFromMnc': '07',
#   'portedFromProviderName': 'Movistar'},
#  {'mcc': '297',
#   'countryName': 'Montenegro',
#   'mnc': '02',
#   'providerName': 'T-Mobile',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '416',
#   'countryName': 'Jordan',
#   'mnc': '77',
#   'providerName': 'Orange',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '340',
#   'countryName': 'Guadeloupe, Martinique and French Guiana',
#   'mnc': '01',
#   'providerName': 'Orange',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '228',
#   'countryName': 'Switzerland',
#   'mnc': '01',
#   'providerName': 'Swisscom',
#   'portedFromMnc': '58',
#   'portedFromProviderName': None},
#  {'mcc': '310',
#   'countryName': 'United States of America',
#   'mnc': '150',
#   'providerName': 'AT&T',
#   'portedFromMnc': '590',
#   'portedFromProviderName': 'Verizon'},
#  {'mcc': '410',
#   'countryName': 'Pakistan',
#   'mnc': '01',
#   'providerName': 'Mobilink',
#   'portedFromMnc': '04',
#   'portedFromProviderName': 'Zong'},
#  {'mcc': '722',
#   'countryName': 'Argentina',
#   'mnc': '340',
#   'providerName': 'Personal',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '250',
#   'countryName': 'Russian Federation',
#   'mnc': '60',
#   'providerName': 'KTK Telecom',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'MTS'},
#  {'mcc': '232',
#   'countryName': 'Austria',
#   'mnc': '01',
#   'providerName': 'A1',
#   'portedFromMnc': '03',
#   'portedFromProviderName': 'Magenta'},
#  {'mcc': '470',
#   'countryName': 'Bangladesh',
#   'mnc': '01',
#   'providerName': 'GrameenPhone',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '405',
#   'countryName': 'India',
#   'mnc': '870',
#   'providerName': 'Jio (UPW)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '714',
#   'countryName': 'Panama',
#   'mnc': '04',
#   'providerName': 'Digicel',
#   'portedFromMnc': '020',
#   'portedFromProviderName': 'Movistar'},
#  {'mcc': '605',
#   'countryName': 'Tunisia',
#   'mnc': '03',
#   'providerName': 'Ooredoo',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Orange'},
#  {'mcc': '284',
#   'countryName': 'Bulgaria',
#   'mnc': '03',
#   'providerName': 'Vivacom',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'A1'},
#  {'mcc': '208',
#   'countryName': 'France',
#   'mnc': '01',
#   'providerName': 'Orange',
#   'portedFromMnc': '15',
#   'portedFromProviderName': 'Free Mobile'},
#  {'mcc': '714',
#   'countryName': 'Panama',
#   'mnc': '03',
#   'providerName': 'Claro',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Cable & Wireless'},
#  {'mcc': '218',
#   'countryName': 'Bosnia and Herzegovina',
#   'mnc': '90',
#   'providerName': 'BH Mobile',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '302',
#   'countryName': 'Canada',
#   'mnc': '220',
#   'providerName': 'Telus Mobility',
#   'portedFromMnc': '720',
#   'portedFromProviderName': 'Rogers Wireless'},
#  {'mcc': '454',
#   'countryName': 'Hong Kong',
#   'mnc': '03',
#   'providerName': '3',
#   'portedFromMnc': '07',
#   'portedFromProviderName': 'China Unicom (MVNO)'},
#  {'mcc': '541',
#   'countryName': 'Vanuatu',
#   'mnc': '01',
#   'providerName': 'SMILE',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '228',
#   'countryName': 'Switzerland',
#   'mnc': '03',
#   'providerName': 'Salt Mobile',
#   'portedFromMnc': '02',
#   'portedFromProviderName': 'Sunrise'},
#  {'mcc': '310',
#   'countryName': 'United States of America',
#   'mnc': '260',
#   'providerName': 'T-Mobile',
#   'portedFromMnc': '120',
#   'portedFromProviderName': 'Sprint'},
#  {'mcc': '302',
#   'countryName': 'Canada',
#   'mnc': '370',
#   'providerName': 'Fido (MVNO)',
#   'portedFromMnc': '610',
#   'portedFromProviderName': 'Bell Mobility'},
#  {'mcc': '400',
#   'countryName': 'Azerbaijan',
#   'mnc': '04',
#   'providerName': 'Nar Mobile',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '214',
#   'countryName': 'Spain',
#   'mnc': '03',
#   'providerName': 'Orange',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '466',
#   'countryName': 'Taiwan',
#   'mnc': '01',
#   'providerName': 'FarEasTone',
#   'portedFromMnc': '89',
#   'portedFromProviderName': 'T Star'},
#  {'mcc': '744',
#   'countryName': 'Paraguay',
#   'mnc': '05',
#   'providerName': 'Personal',
#   'portedFromMnc': '04',
#   'portedFromProviderName': 'Tigo'},
#  {'mcc': '242',
#   'countryName': 'Norway',
#   'mnc': '05',
#   'providerName': 'Network Norway',
#   'portedFromMnc': '23',
#   'portedFromProviderName': 'Lycamobile (MVNO)'},
#  {'mcc': '530',
#   'countryName': 'New Zealand',
#   'mnc': '24',
#   'providerName': '2degrees',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Vodafone'},
#  {'mcc': '702',
#   'countryName': 'Belize',
#   'mnc': '67',
#   'providerName': 'DigiCell',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '282',
#   'countryName': 'Georgia',
#   'mnc': '02',
#   'providerName': 'MagtiCom',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '370',
#   'countryName': 'Dominican Republic',
#   'mnc': '04',
#   'providerName': 'Viva',
#   'portedFromMnc': '02',
#   'portedFromProviderName': 'Claro'},
#  {'mcc': '454',
#   'countryName': 'Hong Kong',
#   'mnc': '03',
#   'providerName': '3',
#   'portedFromMnc': '06',
#   'portedFromProviderName': 'SmarTone'},
#  {'mcc': '440',
#   'countryName': 'Japan',
#   'mnc': '11',
#   'providerName': 'Rakuten',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '404',
#   'countryName': 'India',
#   'mnc': '96',
#   'providerName': 'Airtel (H)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '714',
#   'countryName': 'Panama',
#   'mnc': '020',
#   'providerName': 'Movistar',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '643',
#   'countryName': 'Mozambique',
#   'mnc': '03',
#   'providerName': 'Movitel',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '248',
#   'countryName': 'Estonia',
#   'mnc': '02',
#   'providerName': 'Elisa',
#   'portedFromMnc': '03',
#   'portedFromProviderName': 'Tele2'},
#  {'mcc': '276',
#   'countryName': 'Albania',
#   'mnc': '01',
#   'providerName': 'AMC',
#   'portedFromMnc': '02',
#   'portedFromProviderName': 'Vodafone'},
#  {'mcc': '604',
#   'countryName': 'Morocco',
#   'mnc': '00',
#   'providerName': 'Meditel',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'IAM'},
#  {'mcc': '546',
#   'countryName': 'New Caledonia',
#   'mnc': '01',
#   'providerName': 'Mobilis',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '602',
#   'countryName': 'Egypt',
#   'mnc': '03',
#   'providerName': 'Etisalat',
#   'portedFromMnc': '02',
#   'portedFromProviderName': 'Vodafone'},
#  {'mcc': '364',
# ...
#   'portedFromProviderName': 'Maxis'},
#  {'mcc': '404',
#   'countryName': 'India',
#   'mnc': '98',
#   'providerName': 'Airtel (G)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '226',
#   'countryName': 'Romania',
#   'mnc': '05',
#   'providerName': 'Digi Mobil',
#   'portedFromMnc': '10',
#   'portedFromProviderName': 'Orange'},
#  {'mcc': '238',
#   'countryName': 'Denmark',
#   'mnc': '20',
#   'providerName': 'Telia',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '260',
#   'countryName': 'Poland',
#   'mnc': '09',
#   'providerName': 'Lycamobile (MVNO)',
#   'portedFromMnc': '06',
#   'portedFromProviderName': 'Play'},
#  {'mcc': '404',
#   'countryName': 'India',
#   'mnc': '30',
#   'providerName': 'Vi (Ko)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '214',
#   'countryName': 'Spain',
#   'mnc': '08',
#   'providerName': 'Euskaltel (MVNO)',
#   'portedFromMnc': '04',
#   'portedFromProviderName': 'Yoigo'},
#  {'mcc': '410',
#   'countryName': 'Pakistan',
#   'mnc': '04',
#   'providerName': 'Zong',
#   'portedFromMnc': '03',
#   'portedFromProviderName': 'Ufone'},
#  {'mcc': '208',
#   'countryName': 'France',
#   'mnc': '10',
#   'providerName': 'SFR',
#   'portedFromMnc': '15',
#   'portedFromProviderName': 'Free Mobile'},
#  {'mcc': '278',
#   'countryName': 'Malta',
#   'mnc': '21',
#   'providerName': 'GO',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '302',
#   'countryName': 'Canada',
#   'mnc': '610',
#   'providerName': 'Bell Mobility',
#   'portedFromMnc': '660',
#   'portedFromProviderName': 'MTS'},
#  {'mcc': '655',
#   'countryName': 'South Africa',
#   'mnc': '07',
#   'providerName': 'Cell C',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '234',
#   'countryName': 'United Kingdom',
#   'mnc': '38',
#   'providerName': 'Virgin Mobile',
#   'portedFromMnc': '30',
#   'portedFromProviderName': 'T-Mobile'},
#  {'mcc': '651',
#   'countryName': 'Lesotho',
#   'mnc': '02',
#   'providerName': 'Econet Telecom',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '238',
#   'countryName': 'Denmark',
#   'mnc': '06',
#   'providerName': '3',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '370',
#   'countryName': 'Dominican Republic',
#   'mnc': '02',
#   'providerName': 'Claro',
#   'portedFromMnc': '04',
#   'portedFromProviderName': 'Viva'},
#  {'mcc': '415',
#   'countryName': 'Lebanon',
#   'mnc': '03',
#   'providerName': 'Touch',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '702',
#   'countryName': 'Belize',
#   'mnc': '69',
#   'providerName': 'Smart',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '274',
#   'countryName': 'Iceland',
#   'mnc': '01',
#   'providerName': 'Siminn',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '214',
#   'countryName': 'Spain',
#   'mnc': '06',
#   'providerName': 'Vodafone (MVNO)',
#   'portedFromMnc': '25',
#   'portedFromProviderName': 'Lycamobile (MVNO)'},
#  {'mcc': '420',
#   'countryName': 'Saudi Arabia',
#   'mnc': '04',
#   'providerName': 'Zain',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Al Jawal'},
#  {'mcc': '250',
#   'countryName': 'Russian Federation',
#   'mnc': '62',
#   'providerName': 'Tinkoff Mobile (MVNO)',
#   'portedFromMnc': '99',
#   'portedFromProviderName': 'Beeline'},
#  {'mcc': '338',
#   'countryName': 'Jamaica',
#   'mnc': '050',
#   'providerName': 'Digicel',
#   'portedFromMnc': '070',
#   'portedFromProviderName': 'Claro'},
#  {'mcc': '624',
#   'countryName': 'Cameroon',
#   'mnc': '02',
#   'providerName': 'Orange',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '732',
#   'countryName': 'Colombia',
#   'mnc': '101',
#   'providerName': 'Claro',
#   'portedFromMnc': '111',
#   'portedFromProviderName': 'Tigo'},
#  {'mcc': '740',
#   'countryName': 'Ecuador',
#   'mnc': '00',
#   'providerName': 'Movistar',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Claro'},
#  {'mcc': '736',
#   'countryName': 'Bolivia',
#   'mnc': '02',
#   'providerName': 'Entel',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '257',
#   'countryName': 'Belarus',
#   'mnc': '01',
#   'providerName': 'Velcom',
#   'portedFromMnc': '02',
#   'portedFromProviderName': 'MTS'},
#  {'mcc': '372',
#   'countryName': 'Haiti',
#   'mnc': '02',
#   'providerName': 'Digicel',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '202',
#   'countryName': 'Greece',
#   'mnc': '10',
#   'providerName': 'Wind',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Cosmote'},
#  {'mcc': '404',
#   'countryName': 'India',
#   'mnc': '31',
#   'providerName': 'Airtel (Ko)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '421',
#   'countryName': 'Yemen',
#   'mnc': '04',
#   'providerName': 'Y Telecom',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '232',
#   'countryName': 'Austria',
#   'mnc': '17',
#   'providerName': 'MRS',
#   'portedFromMnc': '07',
#   'portedFromProviderName': 'Magenta-T (MVNO)'},
#  {'mcc': '289',
#   'countryName': 'Abkhazia',
#   'mnc': '67',
#   'providerName': 'Aquafon',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '302',
#   'countryName': 'Canada',
#   'mnc': '660',
#   'providerName': 'MTS',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '234',
#   'countryName': 'United Kingdom',
#   'mnc': '15',
#   'providerName': 'Vodafone',
#   'portedFromMnc': '20',
#   'portedFromProviderName': '3'},
#  {'mcc': '520',
#   'countryName': 'Thailand',
#   'mnc': '99',
#   'providerName': 'True Move',
#   'portedFromMnc': '00',
#   'portedFromProviderName': 'CAT Telecom'},
#  {'mcc': '234',
#   'countryName': 'United Kingdom',
#   'mnc': '57',
#   'providerName': 'Sky UK',
#   'portedFromMnc': '20',
#   'portedFromProviderName': '3'},
#  {'mcc': '425',
#   'countryName': 'Israel',
#   'mnc': '01',
#   'providerName': 'Orange',
#   'portedFromMnc': '16',
#   'portedFromProviderName': 'Rami Levy (MVNO)'},
#  {'mcc': '259',
#   'countryName': 'Moldova',
#   'mnc': '02',
#   'providerName': 'Moldcell',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '202',
#   'countryName': 'Greece',
#   'mnc': '01',
#   'providerName': 'Cosmote',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '636',
#   'countryName': 'Ethiopia',
#   'mnc': '01',
#   'providerName': 'MTN',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '502',
#   'countryName': 'Malaysia',
#   'mnc': '19',
#   'providerName': 'Celcom',
#   'portedFromMnc': '153',
#   'portedFromProviderName': 'Webe'},
#  {'mcc': '404',
#   'countryName': 'India',
#   'mnc': '60',
#   'providerName': 'Vi (R)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '272',
#   'countryName': 'Ireland',
#   'mnc': '05',
#   'providerName': '3',
#   'portedFromMnc': '02',
#   'portedFromProviderName': '3'},
#  {'mcc': '460',
#   'countryName': 'China',
#   'mnc': '03',
#   'providerName': 'China Telecom (CDMA)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '278',
#   'countryName': 'Malta',
#   'mnc': '01',
#   'providerName': 'Vodafone',
#   'portedFromMnc': '77',
#   'portedFromProviderName': 'Melita'},
#  {'mcc': '231',
#   'countryName': 'Slovakia',
#   'mnc': '02',
#   'providerName': 'Telekom',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Orange'},
#  {'mcc': '226',
#   'countryName': 'Romania',
#   'mnc': '10',
#   'providerName': 'Orange',
#   'portedFromMnc': '03',
#   'portedFromProviderName': 'Telekom'},
#  {'mcc': '724',
#   'countryName': 'Brazil',
#   'mnc': '34',
#   'providerName': 'Algar Telecom',
#   'portedFromMnc': '02',
#   'portedFromProviderName': 'TIM'},
#  {'mcc': '247',
#   'countryName': 'Latvia',
#   'mnc': '01',
#   'providerName': 'LMT',
#   'portedFromMnc': '02',
#   'portedFromProviderName': 'Tele2'},
#  {'mcc': '425',
#   'countryName': 'Israel',
#   'mnc': '03',
#   'providerName': 'Pelephone',
#   'portedFromMnc': '08',
#   'portedFromProviderName': 'Golan Telecom'},
#  {'mcc': '401',
#   'countryName': 'Kazakhstan',
#   'mnc': '07',
#   'providerName': 'Altel',
#   'portedFromMnc': '02',
#   'portedFromProviderName': 'Kcell'},
#  {'mcc': '202',
#   'countryName': 'Greece',
#   'mnc': '05',
#   'providerName': 'Vodafone',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '525',
#   'countryName': 'Singapore',
#   'mnc': '10',
#   'providerName': 'TPG Telecom',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '334',
#   'countryName': 'Mexico',
#   'mnc': '070',
#   'providerName': 'Unefon',
#   'portedFromMnc': '020',
#   'portedFromProviderName': 'Telcel'},
#  {'mcc': '310',
#   'countryName': 'United States of America',
#   'mnc': '150',
#   'providerName': 'AT&T',
#   'portedFromMnc': '120',
#   'portedFromProviderName': 'Sprint'},
#  {'mcc': '425',
#   'countryName': 'Israel',
#   'mnc': '07',
#   'providerName': 'Hot Mobile',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '520',
#   'countryName': 'Thailand',
#   'mnc': '18',
#   'providerName': 'dtac',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '505',
#   'countryName': 'Australia',
#   'mnc': '02',
#   'providerName': 'Optus',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '247',
#   'countryName': 'Latvia',
#   'mnc': '05',
#   'providerName': 'Bite',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'LMT'},
#  {'mcc': '302',
#   'countryName': 'Canada',
#   'mnc': '720',
#   'providerName': 'Rogers Wireless',
#   'portedFromMnc': '610',
#   'portedFromProviderName': 'Bell Mobility'},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '56',
#   'providerName': 'Spusu (MVNO)',
#   'portedFromMnc': '50',
#   'portedFromProviderName': 'Iliad'},
#  {'mcc': '214',
#   'countryName': 'Spain',
#   'mnc': '04',
#   'providerName': 'Yoigo',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Vodafone'},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '88',
#   'providerName': 'Wind',
#   'portedFromMnc': '08',
#   'portedFromProviderName': 'Fastweb (MVNO)'},
#  {'mcc': '613',
#   'countryName': 'Burkina Faso',
#   'mnc': '01',
#   'providerName': 'Telmob',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '502',
#   'countryName': 'Malaysia',
#   'mnc': '16',
#   'providerName': 'DiGi',
#   'portedFromMnc': '12',
#   'portedFromProviderName': 'Maxis'},
#  {'mcc': '502',
#   'countryName': 'Malaysia',
#   'mnc': '150',
#   'providerName': 'Tune Talk (MVNO)',
#   'portedFromMnc': '18',
#   'portedFromProviderName': 'U Mobile'},
#  {'mcc': '260',
#   'countryName': 'Poland',
#   'mnc': '03',
#   'providerName': 'Orange',
#   'portedFromMnc': '02',
#   'portedFromProviderName': 'T-mobile'},
#  {'mcc': '470',
#   'countryName': 'Bangladesh',
#   'mnc': '02',
#   'providerName': 'Airtel',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '344',
#   'countryName': 'Antigua and Barbuda',
#   'mnc': '920',
#   'providerName': 'LIME',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '54',
#   'providerName': 'Plintron (MVNO)',
#   'portedFromMnc': '50',
#   'portedFromProviderName': 'Iliad'},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '50',
#   'providerName': 'Iliad',
#   'portedFromMnc': '99',
#   'portedFromProviderName': '3'},
#  {'mcc': '288',
#   'countryName': 'Faroe Islands',
#   'mnc': '01',
#   'providerName': 'Faroese Telecom',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '10',
#   'providerName': 'Vodafone',
#   'portedFromMnc': '36',
#   'portedFromProviderName': 'Digi Mobil (MVNO)'},
#  {'mcc': '609',
#   'countryName': 'Mauritania',
#   'mnc': '02',
#   'providerName': 'Chinguitel',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '404',
#   'countryName': 'India',
#   'mnc': '30',
#   'providerName': 'Vi (Ko)',
#   'portedFromMnc': '81',
#   'portedFromProviderName': 'BSNL Mobile (Ko)'},
#  {'mcc': '232',
#   'countryName': 'Austria',
#   'mnc': '05',
#   'providerName': '3',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '706',
#   'countryName': 'El Salvador',
#   'mnc': '04',
#   'providerName': 'Movistar',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '234',
#   'countryName': 'United Kingdom',
#   'mnc': '38',
#   'providerName': 'Virgin Mobile',
#   'portedFromMnc': '10',
#   'portedFromProviderName': 'O2'},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '33',
#   'providerName': 'Poste Mobile (MVNO)',
#   'portedFromMnc': '99',
#   'portedFromProviderName': '3'},
#  {'mcc': '310',
#   'countryName': 'United States of America',
#   'mnc': '012',
#   'providerName': 'Verizon',
#   'portedFromMnc': '120',
#   'portedFromProviderName': 'Sprint'},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '07',
#   'providerName': 'Noverca (MVNO)',
#   'portedFromMnc': '99',
#   'portedFromProviderName': '3'},
#  {'mcc': '525',
#   'countryName': 'Singapore',
#   'mnc': '03',
#   'providerName': 'M1',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'SingTel'},
#  {'mcc': '234',
#   'countryName': 'United Kingdom',
#   'mnc': '01',
#   'providerName': 'Vectone Mobile (MVNO)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '440',
#   'countryName': 'Japan',
#   'mnc': '11',
#   'providerName': 'Rakuten',
#   'portedFromMnc': '20',
#   'portedFromProviderName': 'SoftBank'},
#  {'mcc': '310',
#   'countryName': 'United States of America',
#   'mnc': '200',
#   'providerName': 'T-Mobile',
#   'portedFromMnc': '012',
#   'portedFromProviderName': 'Verizon'},
#  {'mcc': '272',
#   'countryName': 'Ireland',
#   'mnc': '11',
#   'providerName': 'Tesco Mobile (MVNO)',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'Vodafone'},
#  {'mcc': '232',
#   'countryName': 'Austria',
#   'mnc': '07',
#   'providerName': 'Magenta-T (MVNO)',
#   'portedFromMnc': '05',
#   'portedFromProviderName': '3'},
#  {'mcc': '262',
#   'countryName': 'Germany',
#   'mnc': '01',
#   'providerName': 'T-Mobile',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '222',
#   'countryName': 'Italy',
#   'mnc': '01',
#   'providerName': 'TIM',
#   'portedFromMnc': '33',
#   'portedFromProviderName': 'Poste Mobile (MVNO)'},
#  {'mcc': '405',
#   'countryName': 'India',
#   'mnc': '857',
#   'providerName': 'Jio (G)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '732',
#   'countryName': 'Colombia',
#   'mnc': '187',
#   'providerName': 'eTb',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '724',
#   'countryName': 'Brazil',
#   'mnc': '05',
#   'providerName': 'Claro',
#   'portedFromMnc': '06',
#   'portedFromProviderName': 'Vivo'},
#  {'mcc': '311',
#   'countryName': 'United States of America',
#   'mnc': '660',
#   'providerName': 'Metro (MVNO)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '204',
#   'countryName': 'Netherlands',
#   'mnc': '04',
#   'providerName': 'Vodafone',
#   'portedFromMnc': '16',
#   'portedFromProviderName': 'T-Mobile'},
#  {'mcc': '206',
#   'countryName': 'Belgium',
#   'mnc': '01',
#   'providerName': 'Proximus',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '404',
#   'countryName': 'India',
#   'mnc': '05',
#   'providerName': 'Vi (G)',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '466',
#   'countryName': 'Taiwan',
#   'mnc': '89',
#   'providerName': 'T Star',
#   'portedFromMnc': '05',
#   'portedFromProviderName': 'APTG'},
#  {'mcc': '716',
#   'countryName': 'Peru',
#   'mnc': '15',
#   'providerName': 'Viettel',
#   'portedFromMnc': '06',
#   'portedFromProviderName': 'Movistar'},
#  {'mcc': '525',
#   'countryName': 'Singapore',
#   'mnc': '03',
#   'providerName': 'M1',
#   'portedFromMnc': '10',
#   'portedFromProviderName': 'TPG Telecom'},
#  {'mcc': '730',
#   'countryName': 'Chile',
#   'mnc': '03',
#   'providerName': 'Claro',
#   'portedFromMnc': None,
#   'portedFromProviderName': None},
#  {'mcc': '276',
#   'countryName': 'Albania',
#   'mnc': '02',
#   'providerName': 'Vodafone',
#   'portedFromMnc': '01',
#   'portedFromProviderName': 'AMC'},
#  {'mcc': '250',
#   'countryName': 'Russian Federation',
#   'mnc': '01',
#   'providerName': 'MTS',
#   'portedFromMnc': '20',
#   'portedFromProviderName': 'Tele2'},
#  {'mcc': '262',
#   'countryName': 'Germany',
#   'mnc': '07',
#   'providerName': 'O2',
#   'portedFromMnc': '02',
#   'portedFromProviderName': 'Vodafone'},
#  ...]

# %% [markdown]
# ## Initiate a new tests to the tests endpoint with a single network

# %%
single_network = [{
    "mcc": "429",
    "countryName": "Nepal",
    "mnc": "02",
    "providerName": "Telq",
    "portedFromMnc": "02",
    "portedFromProviderName": None
}]

telq_api.initiate_new_tests(destinationNetworks= single_network, maxCallbackRetries=3, testIdTextType="ALPHA_NUMERIC")
# Out:
# [{'id': 14347765,
#   'testIdText': 'DvyNNv03b4',
#   'phoneNumber': None,
#   'errorMessage': 'NETWORK_OFFLINE',
#   'destinationNetwork': {'mcc': '429', 'mnc': '02', 'portedFromMnc': '02'},
#   'testIdTextType': 'ALPHA_NUMERIC',
#   'testIdTextCase': 'MIXED',
#   'testIdTextLength': 10}]

# %% [markdown]
# ## Initiate a new tests to the tests endpoint with a list of networks

# %%
list_of_networks = [
    {
        "mcc": "246",
        "countryName": "Lithuania",
        "mnc": "03",
        "providerName": "Tele2",
        "portedFromMnc": "02",
        "portedFromProviderName": "BITE",
    },
    {
        "mcc": "364",
        "countryName": "Bahamas",
        "mnc": "49",
        "providerName": "Aliv",
        "portedFromMnc": None,
        "portedFromProviderName": None,
    },
    {
        "mcc": "724",
        "countryName": "Brazil",
        "mnc": "00",
        "providerName": "Nextel",
        "portedFromMnc": None,
        "portedFromProviderName": None,
    },
]

telq_api.initiate_new_tests(destinationNetworks=list_of_networks)
# Out:
# [{'id': 14347790,
#   'testIdText': 'yTzrfFiRxz',
#   'phoneNumber': '37065421053',
#   'errorMessage': None,
#   'destinationNetwork': {'mcc': '246', 'mnc': '03', 'portedFromMnc': '02'},
#   'testIdTextType': 'ALPHA',
#   'testIdTextCase': 'MIXED',
#   'testIdTextLength': 10},
#  {'id': 14347791,
#   'testIdText': 'pEdvNbxaFS',
#   'phoneNumber': '12428080023',
#   'errorMessage': None,
#   'destinationNetwork': {'mcc': '364', 'mnc': '49', 'portedFromMnc': None},
#   'testIdTextType': 'ALPHA',
#   'testIdTextCase': 'MIXED',
#   'testIdTextLength': 10},
#  {'id': 14347792,
#   'testIdText': 'AbkaingotV',
#   'phoneNumber': None,
#   'errorMessage': 'NETWORK_OFFLINE',
#   'destinationNetwork': {'mcc': '724', 'mnc': '00', 'portedFromMnc': None},
#   'testIdTextType': 'ALPHA',
#   'testIdTextCase': 'MIXED',
#   'testIdTextLength': 10}]

# %%
destinationNetworks = [
    {
        "mcc": "246",
        "countryName": "Lithuania",
        "mnc": "03",
        "providerName": "Tele2",
        "portedFromMnc": "02",
        "portedFromProviderName": "BITE",
    },
    {
        "mcc": "364",
        "countryName": "Bahamas",
        "mnc": "49",
        "providerName": "Aliv",
        "portedFromMnc": None,
        "portedFromProviderName": None,
    },
    {
        "mcc": "724",
        "countryName": "Brazil",
        "mnc": "00",
        "providerName": "Nextel",
        "portedFromMnc": None,
        "portedFromProviderName": None,
    },
]

telq_api.initiate_new_tests(
    destinationNetworks=destinationNetworks, 
    resultsCallbackUrl="https://my-callback-url.com/telq_result",
    maxCallbackRetries = 3,
    testIdTextType = "NUMERIC",
    testIdTextLength = 7,
    testTimeToLiveInSeconds = 3000,
)
# Out:
# [{'id': 14347796,
#   'testIdText': '2850015',
#   'phoneNumber': '37065538774',
#   'errorMessage': None,
#   'destinationNetwork': {'mcc': '246', 'mnc': '03', 'portedFromMnc': '02'},
#   'testIdTextType': 'NUMERIC',
#   'testIdTextCase': None,
#   'testIdTextLength': 7},
#  {'id': 14347797,
#   'testIdText': '0817975',
#   'phoneNumber': '12428279187',
#   'errorMessage': None,
#   'destinationNetwork': {'mcc': '364', 'mnc': '49', 'portedFromMnc': None},
#   'testIdTextType': 'NUMERIC',
#   'testIdTextCase': None,
#   'testIdTextLength': 7},
#  {'id': 14347798,
#   'testIdText': '7950300',
#   'phoneNumber': None,
#   'errorMessage': 'NETWORK_OFFLINE',
#   'destinationNetwork': {'mcc': '724', 'mnc': '00', 'portedFromMnc': None},
#   'testIdTextType': 'NUMERIC',
#   'testIdTextCase': None,
#   'testIdTextLength': 7}]

# %% [markdown]
# ## Test Results

# %%
telq_api.get_test_results(14347765)
# Out:
# {'id': 14347765,
#  'testIdText': 'DvyNNv03b4',
#  'senderDelivered': None,
#  'textDelivered': None,
#  'testCreatedAt': '2022-07-12T12:30:36.083748Z',
#  'smsReceivedAt': None,
#  'receiptDelay': None,
#  'testStatus': 'NETWORK_OFFLINE',
#  'destinationNetworkDetails': {'mcc': '429',
#   'mnc': '02',
#   'portedFromMnc': '02',
#   'countryName': 'Nepal',
#   'providerName': 'Ncell',
#   'portedFromProviderName': 'Ncell'},
#  'smscInfo': None,
#  'pdusDelivered': []}
